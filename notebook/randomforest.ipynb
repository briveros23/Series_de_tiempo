# %% [markdown]
# # dependencias

# %%
import pandas as pd
import os
import sys
ruta_carpeta = os.path.abspath('../src')
if ruta_carpeta not in sys.path:
    sys.path.append(ruta_carpeta)
import utilidades as ut
import scipy.stats as stats

# %% [markdown]
# # limpieza de los datos

# %%
datos_diarios = pd.read_excel('../input/delincuancia y clima (1).xlsx')

# %%
datos = datos_diarios.drop(columns=['year','month','number_month','day','number_day','vehicles'])

# %%
datos.head()
# Out:
#         date  interpersviolence  homicides  maxtemp  humid  precipitations  \
# 0 2010-01-01                 31          2       33     78             0.0
# 1 2010-01-02                  6          0       32     82             0.0
# 2 2010-01-03                  8          1       32     76             0.0
# 3 2010-01-04                  7          0       34     81             0.0
# 4 2010-01-05                  3          2       35     83             0.0
#
#    windspeed  moonlight  holidays  weekends  fines  heatindex
# 0       15.4      1.000         1         0      2    26.2516
# 1       16.5      0.987         0         1     13    30.4034
# 2       14.8      0.944         0         1     11    29.7769
# 3       10.7      0.876         0         0      0    30.0638
# 4       13.5      0.787         0         0      0    30.0271

# %%
ut.plot_time_series(datos['homicides'],'2010','D')
